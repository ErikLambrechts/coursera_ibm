# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Erik**
# My desired occupation is data scientist

# %% [markdown]
# *I'm interrested in data science because it seems to be a relavant tool to solve real world problems. I hope that I can find a carreer where I can use this tool to have a meaningfull and positive impact*

# %% [markdown]
# ### The complex calculation of adding one and one

# %%
print(f"{1 + 1 = }")
# Out:
# 1 + 1 = 2

# %% [markdown]
#  - list item 1
#  - list item 2
#
#  ***
#
#  1. First item
#  2. Second item
#
#  ---
#
#  [google](www.google.com)
#
#  ___
#
#
#  | table |
#  |---|
#  | cell |
